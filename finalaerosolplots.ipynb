# %% [markdown]
# # **Honors Thesis Scattering and Absorption Coefficient, AAE, SAE and SSA plots**
# ## By Andre Bergeron
# ## Data source: The University of Utah - Storm Peak Laboratory
# ## Spring 2026

# %%
from main import GetAerosolVariableData

GetAerosolVariableData('absorption', 'coeff', full_data=True)

# %%
GetAerosolVariableData('absorption', 'ssa', full_data=False)
# Out:
# /Users/lberg/Desktop/honors_thesis/aopdataprocessing/Notebooks/main.py:318: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(['J','F','M','A','M','J','J','A','S','O','N','D'], fontsize=16)

# %%
GetAerosolVariableData('scattering', 'angstrom', full_data=False)
# Out:
# /Users/lberg/Desktop/honors_thesis/aopdataprocessing/Notebooks/main.py:318: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(['J','F','M','A','M','J','J','A','S','O','N','D'], fontsize=16)

# %%
GetAerosolVariableData('absorption', 'angstrom', full_data=False)
# Out:
# /Users/lberg/Desktop/honors_thesis/aopdataprocessing/Notebooks/main.py:318: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(['J','F','M','A','M','J','J','A','S','O','N','D'], fontsize=16)
